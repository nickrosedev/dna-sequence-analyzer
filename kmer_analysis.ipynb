# %%
from Bio import SeqIO
import matplotlib.pyplot as plt

# Load your sequence from Week 1
fasta_file = "ncbi_dataset/data/gene.fna"
record = SeqIO.read(fasta_file, "fasta")
sequence = record.seq

print(f"Loaded: {record.id}")
print(f"Length: {len(sequence)} bp")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Load your sequence from Week 1
#       5 fasta_file = "ncbi_dataset/data/gene.fna"
# ----> 6 record = SeqIO.read(fasta_file, "fasta")
#       7 sequence = record.seq
#       9 print(f"Loaded: {record.id}")
#
# File c:\Users\nickr\AppData\Local\Programs\Python\Python313\Lib\site-packages\Bio\SeqIO\__init__.py:719, in read(handle, format, alphabet)
#     679 def read(handle, format, alphabet=None):
#     680     """Turn a sequence file into a single SeqRecord.
#     681
#     682     Arguments:
#    (...)    717     to read multiple records from the handle.
#     718     """
# --> 719     with parse(handle, format, alphabet) as records:
#     720         try:
#     721             record = next(records)
#
# File c:\Users\nickr\AppData\Local\Programs\Python\Python313\Lib\site-packages\Bio\SeqIO\__init__.py:674, in parse(handle, format, alphabet)
#     672 iterator_generator = _FormatToIterator.get(format)
#     673 if iterator_generator:
# --> 674     return iterator_generator(handle)
#     676 raise ValueError(f"Unknown format '{format}'")
#
# File c:\Users\nickr\AppData\Local\Programs\Python\Python313\Lib\site-packages\Bio\SeqIO\FastaIO.py:196, in FastaIterator.__init__(self, source, alphabet)
#     194 if alphabet is not None:
#     195     raise ValueError("The alphabet argument is no longer supported")
# --> 196 super().__init__(source, fmt="Fasta")
#     197 line = self.stream.readline()
#     198 if not line:
#
# File c:\Users\nickr\AppData\Local\Programs\Python\Python313\Lib\site-packages\Bio\SeqIO\Interfaces.py:82, in SequenceIterator.__init__(self, source, alphabet, fmt)
#      80 if isinstance(source, _PathLikeTypes):
#      81     mode = modes[0]
# ---> 82     self.stream = open(source, "r" + mode)
#      83 else:
#      84     value = source.read(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ncbi_dataset/data/gene.fna'
